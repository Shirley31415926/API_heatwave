# %% [markdown]
# <a href="https://colab.research.google.com/github/Shirley31415926/API_heatwave/blob/main/02UK_USA_AND_EU_temp_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In this study, we obtained daily average temperature data from representative GSN (Global Summary of the Day Network) stations in Europe (EU) and the United States (USA), as well as data from 180 stations across the United Kingdom (UK), since the limited geographic extent of the UK may render GSN stations less representative. The data were sourced from the Global Historical Climatology Network (GHCN), maintained by the National Oceanic and Atmospheric Administration (NOAA), and retrieved using the rnoaa package within an R environment running on Google Colab.
#
# A complete list of selected station IDs and associated metadata is available in the GitHub repository folder titled “UK, European and USA temp data.” This folder contains both raw and processed daily average temperature data files for two key periods: June 1 to September 30, 2023, and June 1 to September 30, 2024.
#
# Temperature records were retrieved using the meteo_pull_monitors() function with the variable "TAVG" (average daily temperature). Temperature values were converted from tenths of degrees Celsius to degrees Celsius (°C) by dividing by 10. For each station, data were filtered to exclude missing or incomplete entries.
#
# The final dataset consists of:
# USA: 7,597 valid records
# Europe (EU): 10,944 valid records
# United Kingdom (UK): 4,675 valid records.
#
# All data processing scripts, including station filtering, downloading, cleaning, and aggregation, were written in R language within a notebook environment and are provided in the Code section of the notebook. The scripts are also publicly available through the aforementioned GitHub repository.

# %%
install.packages("devtools")
install.packages("dplyr")
install.packages("readr")
install.packages("progress")
install.packages("purrr")

install.packages("devtools", repos = "https://cloud.r-project.org")
library(devtools)
devtools::install_github("ropensci/rnoaa")
library(rnoaa)

library(dplyr)
library(readr)
library(progress)
library(purrr)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Downloading GitHub repo ropensci/rnoaa@HEAD
# cli       (3.6.4 -> 3.6.5    ) [CRAN]
# triebeard (NA    -> 0.4.1    ) [CRAN]
# rjson     (NA    -> 0.2.23   ) [CRAN]
# scales    (1.3.0 -> 1.4.0    ) [CRAN]
# httpcode  (NA    -> 0.3.0    ) [CRAN]
# urltools  (NA    -> 1.7.3    ) [CRAN]
# hoardr    (NA    -> 0.5.5    ) [CRAN]
# geonames  (NA    -> 0.999    ) [CRAN]
# isdparser (NA    -> 0.4.0    ) [CRAN]
# gridExtra (NA    -> 2.3      ) [CRAN]
# XML       (NA    -> 3.99-0.18) [CRAN]
# crul      (NA    -> 1.5.0    ) [CRAN]
# Installing 12 packages: cli, triebeard, rjson, scales, httpcode, urltools, hoardr, geonames, isdparser, gridExtra, XML, crul
#
# Installing packages into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
# ── R CMD build ─────────────────────────────────────────────────────────────────
# * checking for file ‘/tmp/RtmpVMGpck/remotes19e1d37caef/ropensci-rnoaa-b26b4c5/DESCRIPTION’ ... OK
# * preparing ‘rnoaa’:
# * checking DESCRIPTION meta-information ... OK
# * checking for LF line-endings in source and make files and shell scripts
# * checking for empty or unneeded directories
# Removed empty directory ‘rnoaa/vignettes’
#   NB: this package now depends on R (>= 4.1.0)
#   WARNING: Added dependency on R >= 4.1.0 because package code uses the
#   pipe |> or function shorthand \(...) syntax added in R 4.1.0.
#   File(s) using such syntax:
#     ‘vis_miss.R’
# * building ‘rnoaa_1.4.0.tar.gz’
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# The rnoaa package will soon be retired and archived because the underlying APIs have changed dramatically. The package currently works but does not pull the most recent data in all cases. A noaaWeather package is planned as a replacement but the functions will not be interchangeable.
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
# Download the GHCN stations metadata file
url <- "https://www1.ncdc.noaa.gov/pub/data/ghcn/daily/ghcnd-stations.txt"
download.file(url, destfile = "ghcnd-stations.txt", mode = "wb")

raw_lines <- readLines("ghcnd-stations.txt")

stations <- data.frame(
  id = substr(raw_lines, 1, 11),
  latitude = as.numeric(substr(raw_lines, 13, 20)),
  longitude = as.numeric(substr(raw_lines, 22, 30)),
  elevation = as.numeric(substr(raw_lines, 32, 37)),
  state = substr(raw_lines, 39, 40),
  name = trimws(substr(raw_lines, 42, 71)),
  gsn_flag = substr(raw_lines, 73, 75),
  hcn_flag = substr(raw_lines, 77, 79),
  wmo_id = substr(raw_lines, 81, 85),
  stringsAsFactors = FALSE
)
head(stations)
# Out:
#   id          latitude longitude elevation state name                  gsn_flag
# 1 ACW00011604 17.1167  -61.7833   10.1           ST JOHNS COOLIDGE FLD
# 2 ACW00011647 17.1333  -61.7833   19.2           ST JOHNS
# 3 AE000041196 25.3330   55.5170   34.0           SHARJAH INTER. AIRP   GSN
# 4 AEM00041194 25.2550   55.3640   10.4           DUBAI INTL
# 5 AEM00041217 24.4330   54.6510   26.8           ABU DHABI INTL
# 6 AEM00041218 24.2620   55.6090  264.9           AL AIN INTL
#   hcn_flag wmo_id
# 1
# 2
# 3          41196
# 4          41194
# 5          41217
# 6          41218

# %%
usa_stations <- stations %>%
  filter(substr(id, 1, 2) == "US")
europe_stations <- stations %>%
  filter(latitude > 35 & latitude < 72 & longitude > -10 & longitude < 40)

library(rnoaa)

get_temp_data <- function(ids, region_name) {
  df <- meteo_pull_monitors(monitors = ids,
                            var = "TAVG",
                            date_min = "2023-06-01",
                            date_max = "2023-10-01")
  df$tavg <- df$tavg / 10
  df$region <- region_name
  return(df)
}

# %%
usa_stations <- stations %>%
  filter(substr(id, 1, 2) == "US")

europe_stations <- stations %>%
  filter(latitude > 35 & latitude < 72 & longitude > -10 & longitude < 40)
get_temp_data <- function(ids, region_name) {
  df <- meteo_pull_monitors(monitors = ids,
                            var = "TAVG",
                            date_min = "2023-06-01",
                            date_max = "2023-10-01")
  df$tavg <- df$tavg / 10
  df$region <- region_name
  return(df)
}
get_station_temp <- function(id, region_name) {
  df <- meteo_pull_monitors(monitors = id,
                            var = "TAVG",
                            date_min = "2023-06-01",
                            date_max = "2023-10-01")
  df$tavg <- df$tavg / 10
  df$region <- region_name
  return(df)
}

usa_data <- get_station_temp("USW00094789", "USA")
europe_data <- get_station_temp("FR000007640", "Europe")
# Out:
# file min/max dates: 1948-07-01 / 2025-04-30
#
# Warning message in meteo_pull_monitors(monitors = id, var = "TAVG", date_min = "2023-06-01", :
# “The following stations could not be pulled from the GHCN ftp:
#  FR000007640
# Any other monitors were successfully pulled from GHCN.”
# Warning message:
# “Unknown or uninitialised column: `tavg`.”

# %%
# download GHCN STATION METADATA
url <- "https://www1.ncdc.noaa.gov/pub/data/ghcn/daily/ghcnd-stations.txt"
download.file(url, destfile = "ghcnd-stations.txt", mode = "wb")
raw_lines <- readLines("ghcnd-stations.txt")

# dataframe STRUCTURE
stations <- data.frame(
  id = substr(raw_lines, 1, 11),
  latitude = as.numeric(substr(raw_lines, 13, 20)),
  longitude = as.numeric(substr(raw_lines, 22, 30)),
  elevation = as.numeric(substr(raw_lines, 32, 37)),
  state = substr(raw_lines, 39, 40),
  name = trimws(substr(raw_lines, 42, 71)),
  gsn_flag = substr(raw_lines, 73, 75),
  hcn_flag = substr(raw_lines, 77, 79),
  wmo_id = substr(raw_lines, 81, 85),
  stringsAsFactors = FALSE
)

# %%
library(progress)
library(purrr)

get_multi_station_data <- function(id_list, region_label,
                                   var = "TAVG",
                                   date_min = "2023-06-01",
                                   date_max = "2023-10-01") {
  message(paste("ING", region_label, " ", length(id_list), ""))

  pb <- progress_bar$new(
    format = paste0(region_label, " PROCESS [:bar] :percent | FINISH: :current/:total"),
    total = length(id_list),
    clear = FALSE,
    width = 60
  )

  all_data <- purrr::map_dfr(id_list, function(station_id) {
    pb$tick()
    tryCatch({
      df <- meteo_pull_monitors(monitors = station_id,
                                var = var,
                                date_min = date_min,
                                date_max = date_max)
      df[[tolower(var)]] <- df[[tolower(var)]] /
      df$region <- region_label
      return(df)
    }, error = function(e) {
      return(NULL)
    })
  })

  return(all_data)
}

# %% [markdown]
# # 1.USA GSN station daily mean temperature download 2023

# %%
# ==== Filter USA GSN stations ====
usa_gsn_ids <- stations %>%
  filter(substr(id, 1, 2) == "US", gsn_flag == "GSN") %>%
  pull(id)
length(usa_gsn_ids)

# ==== Define function: fetch TAVG data from multiple stations with progress bar ====
get_multi_station_data <- function(id_list, region_label,
                                   var = "TAVG",
                                   date_min = "2023-06-01",
                                   date_max = "2023-09-30") {
  message(paste("Fetching", region_label, "station data. Total:", length(id_list)))

  pb <- progress_bar$new(
    format = paste0(region_label, " Progress [:bar] :percent | Completed: :current/:total"),
    total = length(id_list),
    clear = FALSE,
    width = 60
  )

  all_data <- purrr::map_dfr(id_list, function(station_id) {
    pb$tick()
    tryCatch({
      df <- meteo_pull_monitors(monitors = station_id,
                                var = var,
                                date_min = date_min,
                                date_max = date_max)
      df[[tolower(var)]] <- df[[tolower(var)]] / 10  # Convert temp from tenths of °C to °C
      df$region <- region_label
      return(df)
    }, error = function(e) {
      return(NULL)
    })
  })

  return(all_data)
}

# ==== Fetch temperature data for USA GSN stations (June–September 2023) ====
usa_data <- get_multi_station_data(usa_gsn_ids, "USA",
                                   var = "TAVG",
                                   date_min = "2023-06-01",
                                   date_max = "2023-09-30")

write.csv(usa_data, "usa_temperature_gsn_2023.csv", row.names = FALSE)

# ==== Clean and summarize daily average temperature ====
usa_clean <- usa_data %>%
  filter(!is.na(tavg))

usa_avg_daily <- usa_clean %>%
  group_by(date) %>%
  summarise(avg_temp = mean(tavg)) %>%
  ungroup()

write.csv(usa_avg_daily, "usa_avg_temperature_2023_Jun-Sep.csv", row.names = FALSE)

# ==== Visualize daily average temperature trend ====
install.packages("ggplot2")
library(ggplot2)
ggplot(usa_avg_daily, aes(x = as.Date(date), y = avg_temp)) +
  geom_line(color = "steelblue", linewidth = 1) +
  labs(
    title = "Daily Average Temperature at USA GSN Stations (Jun 1 – Sep 30, 2023)",
    x = "Date", y = "Average Temperature (°C)"
  ) +
  theme_minimal()
# Out:
# [1] 70
# Fetching USA station data. Total: 70
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USP00CA0003.dly
#
# date created (size, mb): 2025-04-25 11:54:05.936294 (0.015)
#
# file min/max dates: 1863-01-01 / 1865-08-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  USP00CA0003
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00003870.dly
#
# date created (size, mb): 2025-04-25 11:54:15.084241 (7.596)
#
# file min/max dates: 1962-10-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00003945.dly
#
# date created (size, mb): 2025-04-25 11:54:28.796661 (7.221)
#
# file min/max dates: 1969-11-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00012836.dly
#
# date created (size, mb): 2025-04-25 11:54:43.296162 (7.417)
#
# file min/max dates: 1948-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00012842.dly
#
# date created (size, mb): 2025-04-25 11:54:59.064795 (8.899)
#
# file min/max dates: 1939-02-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00012916.dly
#
# date created (size, mb): 2025-04-25 11:55:15.019447 (8.281)
#
# file min/max dates: 1945-10-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00012921.dly
#
# date created (size, mb): 2025-04-25 11:56:42.618517 (8.354)
#
# file min/max dates: 1946-08-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00013722.dly
#
# date created (size, mb): 2025-04-25 11:56:59.233238 (9.325)
#
# file min/max dates: 1944-05-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00013743.dly
#
# date created (size, mb): 2025-04-25 11:57:15.942968 (9.339)
#
# file min/max dates: 1936-09-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00013782.dly
#
# date created (size, mb): 2025-04-25 11:57:26.663078 (3.93)
#
# file min/max dates: 1893-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00013865.dly
#
# date created (size, mb): 2025-04-25 11:57:39.510408 (8.047)
#
# file min/max dates: 1942-03-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00013882.dly
#
# date created (size, mb): 2025-04-25 11:57:54.58797 (8.94)
#
# file min/max dates: 1938-04-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00013957.dly
#
# date created (size, mb): 2025-04-25 11:58:12.975873 (9.399)
#
# file min/max dates: 1939-07-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00013962.dly
#
# date created (size, mb): 2025-04-25 11:58:28.856518 (8.259)
#
# file min/max dates: 1946-08-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00013964.dly
#
# date created (size, mb): 2025-04-25 11:58:44.004086 (8.63)
#
# file min/max dates: 1945-09-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00013967.dly
#
# date created (size, mb): 2025-04-25 11:59:01.268874 (8.81)
#
# file min/max dates: 1941-12-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00013984.dly
#
# date created (size, mb): 2025-04-25 11:59:18.406649 (9.219)
#
# file min/max dates: 1885-05-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00013985.dly
#
# date created (size, mb): 2025-04-25 11:59:36.708544 (9.274)
#
# file min/max dates: 1909-04-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00014607.dly
#
# date created (size, mb): 2025-04-25 11:59:52.705199 (8.585)
#
# file min/max dates: 1939-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00014742.dly
#
# date created (size, mb): 2025-04-25 12:00:09.600948 (9.073)
#
# file min/max dates: 1940-12-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00014753.dly
#
# date created (size, mb): 2025-04-25 12:00:18.564876 (2.117)
#
# file min/max dates: 1998-04-01 / 2024-12-31
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00014755.dly
#
# date created (size, mb): 2025-04-25 12:00:30.540116 (7.929)
#
# file min/max dates: 1948-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00014771.dly
#
# date created (size, mb): 2025-04-25 12:00:46.646783 (9.286)
#
# file min/max dates: 1938-05-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00014838.dly
#
# date created (size, mb): 2025-04-25 12:00:57.634921 (3.844)
#
# file min/max dates: 1857-09-01 / 2025-04-30
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  USW00014838
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00014842.dly
#
# date created (size, mb): 2025-04-25 12:01:12.207429 (9.197)
#
# file min/max dates: 1943-05-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00014922.dly
#
# date created (size, mb): 2025-04-25 12:01:30.012272 (9.347)
#
# file min/max dates: 1938-04-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00014933.dly
#
# date created (size, mb): 2025-04-25 12:01:47.055036 (9.362)
#
# file min/max dates: 1945-07-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00014936.dly
#
# date created (size, mb): 2025-04-25 12:02:07.193121 (11.4)
#
# file min/max dates: 1881-07-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00014941.dly
#
# date created (size, mb): 2025-04-25 12:02:23.954856 (8.124)
#
# file min/max dates: 1945-10-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00021504.dly
#
# date created (size, mb): 2025-04-25 12:02:37.368245 (7.081)
#
# file min/max dates: 1949-10-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00022536.dly
#
# date created (size, mb): 2025-04-25 12:02:51.280685 (8.295)
#
# file min/max dates: 1950-02-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00023044.dly
#
# date created (size, mb): 2025-04-25 12:03:06.98031 (7.922)
#
# file min/max dates: 1938-04-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00023050.dly
#
# date created (size, mb): 2025-04-25 12:03:21.994864 (8.456)
#
# file min/max dates: 1931-03-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00023051.dly
#
# date created (size, mb): 2025-04-25 12:03:35.660279 (6.749)
#
# file min/max dates: 1896-02-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00023066.dly
#
# date created (size, mb): 2025-04-25 12:03:51.662935 (9.467)
#
# file min/max dates: 1900-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00023154.dly
#
# date created (size, mb): 2025-04-25 12:04:09.335765 (8.567)
#
# file min/max dates: 1888-04-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00023169.dly
#
# date created (size, mb): 2025-04-25 12:04:23.558237 (7.086)
#
# file min/max dates: 1948-09-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00023183.dly
#
# date created (size, mb): 2025-04-25 12:04:37.254655 (7.355)
#
# file min/max dates: 1933-06-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00023188.dly
#
# date created (size, mb): 2025-04-25 12:04:51.818162 (7.935)
#
# file min/max dates: 1939-07-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00024011.dly
#
# date created (size, mb): 2025-04-25 12:05:08.425881 (8.89)
#
# file min/max dates: 1936-07-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00024021.dly
#
# date created (size, mb): 2025-04-25 12:05:24.500545 (7.702)
#
# file min/max dates: 1948-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00024023.dly
#
# date created (size, mb): 2025-04-25 12:05:40.00515 (8.707)
#
# file min/max dates: 1948-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00024029.dly
#
# date created (size, mb): 2025-04-25 12:05:54.775679 (7.74)
#
# file min/max dates: 1948-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00024128.dly
#
# date created (size, mb): 2025-04-25 12:06:10.62232 (9.388)
#
# file min/max dates: 1877-07-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00024131.dly
#
# date created (size, mb): 2025-04-25 12:06:28.212141 (8.327)
#
# file min/max dates: 1931-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00024144.dly
#
# date created (size, mb): 2025-04-25 12:06:43.65874 (8.212)
#
# file min/max dates: 1938-04-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00024155.dly
#
# date created (size, mb): 2025-04-25 12:06:58.83131 (8.348)
#
# file min/max dates: 1928-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00024156.dly
#
# date created (size, mb): 2025-04-25 12:07:15.775064 (8.717)
#
# file min/max dates: 1939-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00024213.dly
#
# date created (size, mb): 2025-04-25 12:07:29.050438 (5.868)
#
# file min/max dates: 1941-12-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00024227.dly
#
# date created (size, mb): 2025-04-25 12:07:42.836865 (7.844)
#
# file min/max dates: 1941-05-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00025308.dly
#
# date created (size, mb): 2025-04-25 12:07:56.646295 (7.138)
#
# file min/max dates: 1941-01-01 / 2019-10-31
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00025339.dly
#
# date created (size, mb): 2025-04-25 12:08:12.354922 (9.103)
#
# file min/max dates: 1917-04-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00025503.dly
#
# date created (size, mb): 2025-04-25 12:08:28.749619 (8.612)
#
# file min/max dates: 1942-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00025507.dly
#
# date created (size, mb): 2025-04-25 12:08:44.047203 (7.038)
#
# file min/max dates: 1932-09-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00025624.dly
#
# date created (size, mb): 2025-04-25 12:08:58.653715 (8.174)
#
# file min/max dates: 1942-03-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00025713.dly
#
# date created (size, mb): 2025-04-25 12:09:14.311337 (8.623)
#
# file min/max dates: 1915-08-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00026411.dly
#
# date created (size, mb): 2025-04-25 12:09:29.50391 (8.156)
#
# file min/max dates: 1929-12-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00026510.dly
#
# date created (size, mb): 2025-04-25 12:09:46.143633 (8.407)
#
# file min/max dates: 1939-04-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00026528.dly
#
# date created (size, mb): 2025-04-25 12:10:01.245196 (7.519)
#
# file min/max dates: 1918-06-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00026615.dly
#
# date created (size, mb): 2025-04-25 12:10:16.843812 (8.958)
#
# file min/max dates: 1923-08-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00026616.dly
#
# date created (size, mb): 2025-04-25 12:10:33.710558 (8.498)
#
# file min/max dates: 1897-09-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00026617.dly
#
# date created (size, mb): 2025-04-25 12:10:51.836435 (10.1)
#
# file min/max dates: 1900-08-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00027401.dly
#
# date created (size, mb): 2025-04-25 12:11:02.241512 (3.591)
#
# file min/max dates: 1947-09-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00027502.dly
#
# date created (size, mb): 2025-04-25 12:11:15.980935 (9.334)
#
# file min/max dates: 1901-09-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00093193.dly
#
# date created (size, mb): 2025-04-25 12:11:31.008491 (7.609)
#
# file min/max dates: 1941-12-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00093729.dly
#
# date created (size, mb): 2025-04-25 12:11:44.841923 (7.445)
#
# file min/max dates: 1957-03-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00093817.dly
#
# date created (size, mb): 2025-04-25 12:12:02.219723 (9.366)
#
# file min/max dates: 1948-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00093820.dly
#
# date created (size, mb): 2025-04-25 12:12:20.221586 (10.2)
#
# file min/max dates: 1872-10-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00094008.dly
#
# date created (size, mb): 2025-04-25 12:12:36.053226 (6.986)
#
# file min/max dates: 1942-12-01 / 2018-03-31
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00094823.dly
#
# date created (size, mb): 2025-04-25 12:18:50.574006 (9.346)
#
# file min/max dates: 1945-02-01 / 2025-04-30
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
# plot without title

# %% [markdown]
# # 2.USA GSN station daily mean temperature download 2024

# %%
get_multi_station_data <- function(id_list, region_label,
                                   var = "TAVG",
                                   date_min = "2024-06-01",
                                   date_max = "2024-09-30") {
  message(paste("Fetching", region_label, "station data. Total:", length(id_list)))

  pb <- progress_bar$new(
    format = paste0(region_label, " Progress [:bar] :percent | Completed: :current/:total"),
    total = length(id_list),
    clear = FALSE,
    width = 60
  )

  all_data <- purrr::map_dfr(id_list, function(station_id) {
    pb$tick()
    tryCatch({
      df <- meteo_pull_monitors(monitors = station_id,
                                var = var,
                                date_min = date_min,
                                date_max = date_max)
      df[[tolower(var)]] <- df[[tolower(var)]] / 10
      df$region <- region_label
      return(df)
    }, error = function(e) {
      return(NULL)
    })
  })

  return(all_data)
}

# ==== Fetch temperature data for USA GSN stations (June–September 2024) ====
usa_data <- get_multi_station_data(usa_gsn_ids, "USA",
                                   var = "TAVG",
                                   date_min = "2024-06-01",
                                   date_max = "2024-09-30")
write.csv(usa_data, "usa_temperature_gsn_2024.csv", row.names = FALSE)

# ==== Clean and summarize daily average temperature ====
usa_clean <- usa_data %>%
  filter(!is.na(tavg))
usa_avg_daily <- usa_clean %>%
  group_by(date) %>%
  summarise(avg_temp = mean(tavg)) %>%
  ungroup()
write.csv(usa_avg_daily, "usa_avg_temperature_2024_Jun-Sep.csv", row.names = FALSE)

ggplot(usa_avg_daily, aes(x = as.Date(date), y = avg_temp)) +
  geom_line(color = "steelblue", linewidth = 1) +
  labs(
    title = "Daily Average Temperature at USA GSN Stations (Jun 1 – Sep 30, 2024)",
    x = "Date", y = "Average Temperature (°C)"
  ) +
  theme_minimal()
# Out:
# Fetching USA station data. Total: 70
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USP00CA0003.dly
#
# date created (size, mb): 2025-04-25 11:54:05.936294 (0.015)
#
# file min/max dates: 1863-01-01 / 1865-08-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  USP00CA0003
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00003870.dly
#
# date created (size, mb): 2025-04-25 11:54:15.084241 (7.596)
#
# file min/max dates: 1962-10-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00003945.dly
#
# date created (size, mb): 2025-04-25 11:54:28.796661 (7.221)
#
# file min/max dates: 1969-11-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00012836.dly
#
# date created (size, mb): 2025-04-25 11:54:43.296162 (7.417)
#
# file min/max dates: 1948-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00012842.dly
#
# date created (size, mb): 2025-04-25 11:54:59.064795 (8.899)
#
# file min/max dates: 1939-02-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00012916.dly
#
# date created (size, mb): 2025-04-25 11:55:15.019447 (8.281)
#
# file min/max dates: 1945-10-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00012921.dly
#
# date created (size, mb): 2025-04-25 11:56:42.618517 (8.354)
#
# file min/max dates: 1946-08-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00013722.dly
#
# date created (size, mb): 2025-04-25 11:56:59.233238 (9.325)
#
# file min/max dates: 1944-05-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00013743.dly
#
# date created (size, mb): 2025-04-25 11:57:15.942968 (9.339)
#
# file min/max dates: 1936-09-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00013782.dly
#
# date created (size, mb): 2025-04-25 11:57:26.663078 (3.93)
#
# file min/max dates: 1893-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00013865.dly
#
# date created (size, mb): 2025-04-25 11:57:39.510408 (8.047)
#
# file min/max dates: 1942-03-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00013882.dly
#
# date created (size, mb): 2025-04-25 11:57:54.58797 (8.94)
#
# file min/max dates: 1938-04-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00013957.dly
#
# date created (size, mb): 2025-04-25 11:58:12.975873 (9.399)
#
# file min/max dates: 1939-07-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00013962.dly
#
# date created (size, mb): 2025-04-25 11:58:28.856518 (8.259)
#
# file min/max dates: 1946-08-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00013964.dly
#
# date created (size, mb): 2025-04-25 11:58:44.004086 (8.63)
#
# file min/max dates: 1945-09-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00013967.dly
#
# date created (size, mb): 2025-04-25 11:59:01.268874 (8.81)
#
# file min/max dates: 1941-12-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00013984.dly
#
# date created (size, mb): 2025-04-25 11:59:18.406649 (9.219)
#
# file min/max dates: 1885-05-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00013985.dly
#
# date created (size, mb): 2025-04-25 11:59:36.708544 (9.274)
#
# file min/max dates: 1909-04-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00014607.dly
#
# date created (size, mb): 2025-04-25 11:59:52.705199 (8.585)
#
# file min/max dates: 1939-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00014742.dly
#
# date created (size, mb): 2025-04-25 12:00:09.600948 (9.073)
#
# file min/max dates: 1940-12-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00014753.dly
#
# date created (size, mb): 2025-04-25 12:00:18.564876 (2.117)
#
# file min/max dates: 1998-04-01 / 2024-12-31
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00014755.dly
#
# date created (size, mb): 2025-04-25 12:00:30.540116 (7.929)
#
# file min/max dates: 1948-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00014771.dly
#
# date created (size, mb): 2025-04-25 12:00:46.646783 (9.286)
#
# file min/max dates: 1938-05-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00014838.dly
#
# date created (size, mb): 2025-04-25 12:00:57.634921 (3.844)
#
# file min/max dates: 1857-09-01 / 2025-04-30
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  USW00014838
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00014842.dly
#
# date created (size, mb): 2025-04-25 12:01:12.207429 (9.197)
#
# file min/max dates: 1943-05-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00014922.dly
#
# date created (size, mb): 2025-04-25 12:01:30.012272 (9.347)
#
# file min/max dates: 1938-04-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00014933.dly
#
# date created (size, mb): 2025-04-25 12:01:47.055036 (9.362)
#
# file min/max dates: 1945-07-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00014936.dly
#
# date created (size, mb): 2025-04-25 12:02:07.193121 (11.4)
#
# file min/max dates: 1881-07-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00014941.dly
#
# date created (size, mb): 2025-04-25 12:02:23.954856 (8.124)
#
# file min/max dates: 1945-10-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00021504.dly
#
# date created (size, mb): 2025-04-25 12:02:37.368245 (7.081)
#
# file min/max dates: 1949-10-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00022536.dly
#
# date created (size, mb): 2025-04-25 12:02:51.280685 (8.295)
#
# file min/max dates: 1950-02-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00023044.dly
#
# date created (size, mb): 2025-04-25 12:03:06.98031 (7.922)
#
# file min/max dates: 1938-04-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00023050.dly
#
# date created (size, mb): 2025-04-25 12:03:21.994864 (8.456)
#
# file min/max dates: 1931-03-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00023051.dly
#
# date created (size, mb): 2025-04-25 12:03:35.660279 (6.749)
#
# file min/max dates: 1896-02-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00023066.dly
#
# date created (size, mb): 2025-04-25 12:03:51.662935 (9.467)
#
# file min/max dates: 1900-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00023154.dly
#
# date created (size, mb): 2025-04-25 12:04:09.335765 (8.567)
#
# file min/max dates: 1888-04-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00023169.dly
#
# date created (size, mb): 2025-04-25 12:04:23.558237 (7.086)
#
# file min/max dates: 1948-09-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00023183.dly
#
# date created (size, mb): 2025-04-25 12:04:37.254655 (7.355)
#
# file min/max dates: 1933-06-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00023188.dly
#
# date created (size, mb): 2025-04-25 12:04:51.818162 (7.935)
#
# file min/max dates: 1939-07-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00024011.dly
#
# date created (size, mb): 2025-04-25 12:05:08.425881 (8.89)
#
# file min/max dates: 1936-07-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00024021.dly
#
# date created (size, mb): 2025-04-25 12:05:24.500545 (7.702)
#
# file min/max dates: 1948-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00024023.dly
#
# date created (size, mb): 2025-04-25 12:05:40.00515 (8.707)
#
# file min/max dates: 1948-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00024029.dly
#
# date created (size, mb): 2025-04-25 12:05:54.775679 (7.74)
#
# file min/max dates: 1948-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00024128.dly
#
# date created (size, mb): 2025-04-25 12:06:10.62232 (9.388)
#
# file min/max dates: 1877-07-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00024131.dly
#
# date created (size, mb): 2025-04-25 12:06:28.212141 (8.327)
#
# file min/max dates: 1931-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00024144.dly
#
# date created (size, mb): 2025-04-25 12:06:43.65874 (8.212)
#
# file min/max dates: 1938-04-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00024155.dly
#
# date created (size, mb): 2025-04-25 12:06:58.83131 (8.348)
#
# file min/max dates: 1928-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00024156.dly
#
# date created (size, mb): 2025-04-25 12:07:15.775064 (8.717)
#
# file min/max dates: 1939-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00024213.dly
#
# date created (size, mb): 2025-04-25 12:07:29.050438 (5.868)
#
# file min/max dates: 1941-12-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00024227.dly
#
# date created (size, mb): 2025-04-25 12:07:42.836865 (7.844)
#
# file min/max dates: 1941-05-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00025308.dly
#
# date created (size, mb): 2025-04-25 12:07:56.646295 (7.138)
#
# file min/max dates: 1941-01-01 / 2019-10-31
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00025339.dly
#
# date created (size, mb): 2025-04-25 12:08:12.354922 (9.103)
#
# file min/max dates: 1917-04-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00025503.dly
#
# date created (size, mb): 2025-04-25 12:08:28.749619 (8.612)
#
# file min/max dates: 1942-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00025507.dly
#
# date created (size, mb): 2025-04-25 12:08:44.047203 (7.038)
#
# file min/max dates: 1932-09-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00025624.dly
#
# date created (size, mb): 2025-04-25 12:08:58.653715 (8.174)
#
# file min/max dates: 1942-03-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00025713.dly
#
# date created (size, mb): 2025-04-25 12:09:14.311337 (8.623)
#
# file min/max dates: 1915-08-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00026411.dly
#
# date created (size, mb): 2025-04-25 12:09:29.50391 (8.156)
#
# file min/max dates: 1929-12-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00026510.dly
#
# date created (size, mb): 2025-04-25 12:09:46.143633 (8.407)
#
# file min/max dates: 1939-04-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00026528.dly
#
# date created (size, mb): 2025-04-25 12:10:01.245196 (7.519)
#
# file min/max dates: 1918-06-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00026615.dly
#
# date created (size, mb): 2025-04-25 12:10:16.843812 (8.958)
#
# file min/max dates: 1923-08-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00026616.dly
#
# date created (size, mb): 2025-04-25 12:10:33.710558 (8.498)
#
# file min/max dates: 1897-09-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00026617.dly
#
# date created (size, mb): 2025-04-25 12:10:51.836435 (10.1)
#
# file min/max dates: 1900-08-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00027401.dly
#
# date created (size, mb): 2025-04-25 12:11:02.241512 (3.591)
#
# file min/max dates: 1947-09-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00027502.dly
#
# date created (size, mb): 2025-04-25 12:11:15.980935 (9.334)
#
# file min/max dates: 1901-09-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00093193.dly
#
# date created (size, mb): 2025-04-25 12:11:31.008491 (7.609)
#
# file min/max dates: 1941-12-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00093729.dly
#
# date created (size, mb): 2025-04-25 12:11:44.841923 (7.445)
#
# file min/max dates: 1957-03-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00093817.dly
#
# date created (size, mb): 2025-04-25 12:12:02.219723 (9.366)
#
# file min/max dates: 1948-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00093820.dly
#
# date created (size, mb): 2025-04-25 12:12:20.221586 (10.2)
#
# file min/max dates: 1872-10-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00094008.dly
#
# date created (size, mb): 2025-04-25 12:12:36.053226 (6.986)
#
# file min/max dates: 1942-12-01 / 2018-03-31
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/USW00094823.dly
#
# date created (size, mb): 2025-04-25 12:18:50.574006 (9.346)
#
# file min/max dates: 1945-02-01 / 2025-04-30
# plot without title

# %% [markdown]
# # 3.UK GSN station daily mean temperature download 2023

# %%
#Filter UK stations based on geographic bounds
uk_ids <- stations %>%
  filter(latitude > 49, latitude < 61,
         longitude > -11, longitude < 2) %>%
  pull(id)

length(uk_ids)

uk_data <- get_multi_station_data(uk_ids, "UK",
                                  var = "TAVG",
                                  date_min = "2023-06-01",
                                  date_max = "2023-09-30")

write.csv(uk_data, "uk_temperature_gsn_2023.csv", row.names = FALSE)

uk_clean <- uk_data %>%
  filter(!is.na(tavg))

uk_avg_daily <- uk_clean %>%
  group_by(date) %>%
  summarise(avg_temp = mean(tavg)) %>%
  ungroup()

write.csv(uk_avg_daily, "uk_avg_temperature_2023_Jun-Sep.csv", row.names = FALSE)

ggplot(uk_avg_daily, aes(x = as.Date(date), y = avg_temp)) +
  geom_line(color = "darkgreen", linewidth = 1) +
  labs(
    title = "Daily Average Temperature at UK GSN Stations (Jun 1 – Sep 30, 2023)",
    x = "Date", y = "Average Temperature (°C)"
  ) +
  theme_minimal()
# Out:
# [1] 180
# Fetching UK station data. Total: 180
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/EI000003953.dly
#
# date created (size, mb): 2025-04-25 12:34:45.014839 (2.035)
#
# file min/max dates: 1929-10-01 / 2025-04-30
#
# file min/max dates: 1954-10-01 / 2009-11-30
#
# file min/max dates: 1867-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/EI000003980.dly
#
# date created (size, mb): 2025-04-25 12:34:49.970352 (2.179)
#
# file min/max dates: 1885-01-01 / 2025-02-28
#
# file min/max dates: 1861-01-01 / 2002-12-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  EIE00101859
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1941-01-01 / 2024-11-30
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  EIE00107762
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1945-11-01 / 2024-11-30
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  EIE00107808
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1973-01-01 / 2025-01-31
#
# file min/max dates: 2007-08-01 / 2025-04-30
#
# file min/max dates: 1973-01-01 / 2007-07-31
#
# file min/max dates: 1973-01-01 / 2025-04-30
#
# file min/max dates: 1987-02-01 / 2025-04-30
#
# file min/max dates: 1929-10-01 / 2025-04-30
#
# file min/max dates: 1973-01-01 / 2025-04-30
#
# file min/max dates: 1922-05-01 / 2025-02-28
#
# file min/max dates: 1944-10-01 / 2025-02-28
#
# file min/max dates: 1880-01-01 / 2025-02-28
#
# file min/max dates: 1968-03-01 / 2025-03-31
#
# file min/max dates: 1940-06-01 / 2025-01-31
#
# file min/max dates: 1973-01-01 / 2025-01-31
#
# file min/max dates: 1973-01-01 / 2025-03-31
#
# file min/max dates: 1954-10-01 / 1967-06-30
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  FRW00034061
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1880-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UK000000000
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UK000003005.dly
#
# date created (size, mb): 2025-04-25 12:34:54.591831 (2.247)
#
# file min/max dates: 1929-10-01 / 2025-03-31
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UK000003026.dly
#
# date created (size, mb): 2025-04-25 12:34:59.494339 (2.908)
#
# file min/max dates: 1873-07-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UK000003162.dly
#
# date created (size, mb): 2025-04-25 12:35:04.234829 (1.854)
#
# file min/max dates: 1931-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UK000003302.dly
#
# date created (size, mb): 2025-04-25 12:35:08.017221 (1.916)
#
# file min/max dates: 1930-12-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UK000003377.dly
#
# date created (size, mb): 2025-04-25 12:35:11.666599 (1.843)
#
# file min/max dates: 1949-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UK000003808.dly
#
# date created (size, mb): 2025-04-25 12:35:15.189964 (1.275)
#
# file min/max dates: 1973-01-01 / 2025-04-30
#
# file min/max dates: 1931-01-01 / 1999-12-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UK000044841
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1838-01-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UK000047811
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1814-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UK000056225
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1929-10-01 / 2025-04-30
#
# file min/max dates: 1905-05-01 / 2010-09-30
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00100808
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1959-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00102158
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1898-01-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105003
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 2000-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105630
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 2000-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105636
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 2000-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105642
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 2000-12-01 / 2024-12-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105648
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 2000-12-01 / 2005-10-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105651
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 2000-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105657
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1914-01-01 / 2011-03-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105660
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 2000-12-01 / 2011-06-30
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105669
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 2000-12-01 / 2024-09-30
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105672
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 2000-12-01 / 2002-06-30
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105675
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 2000-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105681
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1959-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105856
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1959-12-01 / 2013-10-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105857
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1960-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105858
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1906-01-01 / 2021-07-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105860
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1960-01-01 / 2007-04-30
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105861
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1959-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105862
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1920-12-01 / 2004-12-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105863
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1960-11-01 / 2004-06-30
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105864
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1959-12-01 / 2013-01-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105865
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1959-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105866
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1959-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105867
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1959-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105869
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1959-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105870
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1960-04-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105871
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1959-12-01 / 2008-11-30
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105872
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1959-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105873
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1959-12-01 / 2005-04-30
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105874
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1959-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105875
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1959-12-01 / 2024-08-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105876
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1959-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105877
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1961-08-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105878
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1959-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105880
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1959-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105881
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1959-12-01 / 2023-10-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105882
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1959-12-01 / 2017-08-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105884
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1959-12-01 / 2022-01-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105885
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1959-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105886
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1959-12-01 / 2022-12-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105887
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1959-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105888
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1959-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105889
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1959-12-01 / 2006-04-30
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105890
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1959-12-01 / 2023-06-30
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105891
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1959-12-01 / 2023-03-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105892
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1959-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105893
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1959-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105894
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1903-12-01 / 2017-12-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105895
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1959-12-01 / 2024-11-30
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105897
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1959-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105898
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1889-01-01 / 2004-12-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105899
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1916-01-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105900
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1959-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105901
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1959-12-01 / 2022-08-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105902
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1910-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105903
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1882-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105904
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1874-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105905
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1959-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105906
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1959-12-01 / 2006-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105907
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1959-12-01 / 2002-12-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105908
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1959-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105909
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1959-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105910
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1899-12-01 / 2008-10-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105911
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1959-12-01 / 2004-10-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105912
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1959-12-01 / 2024-11-30
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105913
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1959-12-01 / 2014-11-30
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105914
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1959-12-01 / 2016-07-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105915
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1959-12-01 / 2006-03-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105917
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1960-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105918
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1959-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105919
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1910-12-01 / 2024-12-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105920
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1959-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105921
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1960-03-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105922
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1959-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105923
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1959-12-01 / 2003-09-30
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105924
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1959-12-01 / 2012-12-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105925
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1959-12-01 / 2024-10-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105926
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1959-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105927
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1959-12-01 / 2009-11-30
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105929
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1959-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105930
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1959-12-01 / 2012-12-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105931
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1959-12-01 / 2017-09-30
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105932
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1959-12-01 / 2006-10-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105933
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1959-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00107640
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1959-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00107650
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1959-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00107663
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1964-08-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00107962
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1959-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00108854
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1959-12-01 / 2007-07-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00108855
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 2005-06-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00115807
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 2004-12-01 / 2010-10-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00115811
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 2012-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00156832
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 2012-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00156836
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 2012-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00156840
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 2012-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00156844
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 2012-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00156848
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1879-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00156852
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 2012-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00156856
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 2012-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00156860
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 2012-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00156864
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 2012-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00156868
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 2012-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00156872
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 2012-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00156876
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 2013-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00156880
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1904-02-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00156884
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 2013-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00156888
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1984-08-01 / 2016-04-30
#
# file min/max dates: 1973-01-01 / 2025-04-30
#
# file min/max dates: 1973-01-01 / 2025-04-30
#
# file min/max dates: 1929-10-01 / 2025-04-30
#
# file min/max dates: 1937-03-01 / 2025-04-30
#
# file min/max dates: 1973-01-01 / 2025-04-30
#
# file min/max dates: 1973-01-01 / 2025-04-30
#
# file min/max dates: 1973-01-01 / 2008-01-31
#
# file min/max dates: 1973-01-01 / 2025-04-30
#
# file min/max dates: 1973-01-01 / 2025-04-30
#
# file min/max dates: 1973-01-01 / 2025-04-30
#
# file min/max dates: 1973-01-01 / 2025-04-30
#
# file min/max dates: 1948-12-01 / 2025-04-30
#
# file min/max dates: 1973-01-01 / 2025-04-30
#
# file min/max dates: 1939-08-01 / 2025-04-30
#
# file min/max dates: 1954-03-01 / 1957-04-30
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKW00015014
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1956-06-01 / 1962-08-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKW00015015
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1950-11-01 / 1951-10-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKW00015018
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1946-01-01 / 1959-04-30
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKW00015027
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1955-09-01 / 1967-12-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKW00015033
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1950-10-01 / 1951-12-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKW00015034
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1950-09-01 / 1951-03-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKW00015035
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1951-08-01 / 1965-04-30
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKW00015036
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1951-11-01 / 1967-12-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKW00015037
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1952-06-01 / 1964-06-30
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKW00015038
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1954-01-01 / 1967-04-30
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKW00015040
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1954-10-01 / 1957-03-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKW00015041
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1957-07-01 / 1962-08-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKW00015042
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1949-05-01 / 1967-12-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKW00035034
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1949-04-01 / 1951-01-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKW00035035
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1949-06-01 / 1964-03-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKW00035036
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1950-07-01 / 1967-12-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKW00035046
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1935-10-01 / 2025-04-30
#
# file min/max dates: 1951-06-01 / 1967-12-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKW00035048
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1951-07-01 / 1958-12-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKW00035049
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1952-05-01 / 1967-12-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKW00035050
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1952-11-01 / 1967-12-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKW00035051
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1954-12-01 / 1958-08-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKW00035052
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1960-12-01 / 1964-06-30
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKW00035054
# Any other monitors were successfully pulled from GHCN.”
# plot without title

# %% [markdown]
# # 4.UK GSN station daily mean temperature download 2024

# %%
#Filter UK stations based on geographic bounds
uk_ids <- stations %>%
  filter(latitude > 49, latitude < 61,
         longitude > -11, longitude < 2) %>%
  pull(id)

length(uk_ids)

uk_data <- get_multi_station_data(uk_ids, "UK",
                                  var = "TAVG",
                                  date_min = "2024-06-01",
                                  date_max = "2024-09-30")

write.csv(uk_data, "uk_temperature_gsn_2024.csv", row.names = FALSE)

uk_clean <- uk_data %>%
  filter(!is.na(tavg))

uk_avg_daily <- uk_clean %>%
  group_by(date) %>%
  summarise(avg_temp = mean(tavg)) %>%
  ungroup()

write.csv(uk_avg_daily, "uk_avg_temperature_2024_Jun-Sep.csv", row.names = FALSE)

ggplot(uk_avg_daily, aes(x = as.Date(date), y = avg_temp)) +
  geom_line(color = "darkgreen", linewidth = 1) +
  labs(
    title = "Daily Average Temperature at UK GSN Stations (Jun 1 – Sep 30, 2024)",
    x = "Date", y = "Average Temperature (°C)"
  ) +
  theme_minimal()
# Out:
# [1] 180
# Fetching UK station data. Total: 180
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/EI000003953.dly
#
# date created (size, mb): 2025-04-25 12:34:45.014839 (2.035)
#
# file min/max dates: 1929-10-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/EI000003965.dly
#
# date created (size, mb): 2025-04-25 12:37:00.930913 (1.236)
#
# file min/max dates: 1954-10-01 / 2009-11-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/EI000003969.dly
#
# date created (size, mb): 2025-04-25 12:37:05.936431 (3.176)
#
# file min/max dates: 1867-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/EI000003980.dly
#
# date created (size, mb): 2025-04-25 12:34:49.970352 (2.179)
#
# file min/max dates: 1885-01-01 / 2025-02-28
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/EIE00101859.dly
#
# date created (size, mb): 2025-04-25 12:37:12.483109 (1.932)
#
# file min/max dates: 1861-01-01 / 2002-12-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  EIE00101859
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/EIE00107762.dly
#
# date created (size, mb): 2025-04-25 12:37:15.181388 (1.038)
#
# file min/max dates: 1941-01-01 / 2024-11-30
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  EIE00107762
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/EIE00107808.dly
#
# date created (size, mb): 2025-04-25 12:37:17.500628 (1.158)
#
# file min/max dates: 1945-11-01 / 2024-11-30
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  EIE00107808
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/EIM00003955.dly
#
# date created (size, mb): 2025-04-25 12:37:20.403929 (1.227)
#
# file min/max dates: 1973-01-01 / 2025-01-31
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/EIM00003956.dly
#
# date created (size, mb): 2025-04-25 12:37:22.322128 (0.408)
#
# file min/max dates: 2007-08-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/EIM00003957.dly
#
# date created (size, mb): 2025-04-25 12:37:24.219324 (0.796)
#
# file min/max dates: 1973-01-01 / 2007-07-31
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/EIM00003962.dly
#
# date created (size, mb): 2025-04-25 12:37:26.641575 (1.198)
#
# file min/max dates: 1973-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/EIM00003967.dly
#
# date created (size, mb): 2025-04-25 12:37:28.757794 (0.901)
#
# file min/max dates: 1987-02-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/EIM00003973.dly
#
# date created (size, mb): 2025-04-25 12:37:31.097036 (0.898)
#
# file min/max dates: 1929-10-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/EIM00003976.dly
#
# date created (size, mb): 2025-04-25 12:37:33.897326 (1.218)
#
# file min/max dates: 1973-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/FRE00104036.dly
#
# date created (size, mb): 2025-04-25 12:37:38.28078 (2.135)
#
# file min/max dates: 1922-05-01 / 2025-02-28
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/FRE00104044.dly
#
# date created (size, mb): 2025-04-25 12:37:41.928158 (1.781)
#
# file min/max dates: 1944-10-01 / 2025-02-28
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/FRE00104937.dly
#
# date created (size, mb): 2025-04-25 12:37:46.417623 (2.071)
#
# file min/max dates: 1880-01-01 / 2025-02-28
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/FRE00106184.dly
#
# date created (size, mb): 2025-04-25 12:37:50.198014 (1.396)
#
# file min/max dates: 1968-03-01 / 2025-03-31
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/FRM00007005.dly
#
# date created (size, mb): 2025-04-25 12:37:52.901294 (1.266)
#
# file min/max dates: 1940-06-01 / 2025-01-31
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/FRM00007027.dly
#
# date created (size, mb): 2025-04-25 12:37:55.605574 (1.227)
#
# file min/max dates: 1973-01-01 / 2025-01-31
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/FRM00007037.dly
#
# date created (size, mb): 2025-04-25 12:37:59.995029 (1.266)
#
# file min/max dates: 1973-01-01 / 2025-03-31
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/FRW00034061.dly
#
# date created (size, mb): 2025-04-25 12:38:02.195256 (0.809)
#
# file min/max dates: 1954-10-01 / 1967-06-30
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  FRW00034061
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UK000000000.dly
#
# date created (size, mb): 2025-04-25 12:38:05.574606 (1.759)
#
# file min/max dates: 1880-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UK000000000
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UK000003005.dly
#
# date created (size, mb): 2025-04-25 12:34:54.591831 (2.247)
#
# file min/max dates: 1929-10-01 / 2025-03-31
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UK000003026.dly
#
# date created (size, mb): 2025-04-25 12:34:59.494339 (2.908)
#
# file min/max dates: 1873-07-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UK000003162.dly
#
# date created (size, mb): 2025-04-25 12:35:04.234829 (1.854)
#
# file min/max dates: 1931-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UK000003302.dly
#
# date created (size, mb): 2025-04-25 12:35:08.017221 (1.916)
#
# file min/max dates: 1930-12-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UK000003377.dly
#
# date created (size, mb): 2025-04-25 12:35:11.666599 (1.843)
#
# file min/max dates: 1949-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UK000003808.dly
#
# date created (size, mb): 2025-04-25 12:35:15.189964 (1.275)
#
# file min/max dates: 1973-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UK000044841.dly
#
# date created (size, mb): 2025-04-25 12:38:15.433627 (0.394)
#
# file min/max dates: 1931-01-01 / 1999-12-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UK000044841
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UK000047811.dly
#
# date created (size, mb): 2025-04-25 12:38:20.042104 (3.278)
#
# file min/max dates: 1838-01-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UK000047811
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UK000056225.dly
#
# date created (size, mb): 2025-04-25 12:38:27.775905 (3.695)
#
# file min/max dates: 1814-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UK000056225
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UK000070765.dly
#
# date created (size, mb): 2025-04-25 12:38:32.782424 (2.143)
#
# file min/max dates: 1929-10-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00100808.dly
#
# date created (size, mb): 2025-04-25 12:38:37.760939 (1.816)
#
# file min/max dates: 1905-05-01 / 2010-09-30
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00100808
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00102158.dly
#
# date created (size, mb): 2025-04-25 12:38:40.910265 (1.454)
#
# file min/max dates: 1959-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00102158
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105003.dly
#
# date created (size, mb): 2025-04-25 12:38:43.059488 (0.702)
#
# file min/max dates: 1898-01-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105003
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105630.dly
#
# date created (size, mb): 2025-04-25 12:38:44.808669 (0.535)
#
# file min/max dates: 2000-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105630
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105636.dly
#
# date created (size, mb): 2025-04-25 12:38:46.512845 (0.497)
#
# file min/max dates: 2000-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105636
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105642.dly
#
# date created (size, mb): 2025-04-25 12:38:49.393144 (0.433)
#
# file min/max dates: 2000-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105642
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105648.dly
#
# date created (size, mb): 2025-04-25 12:38:50.865296 (0.426)
#
# file min/max dates: 2000-12-01 / 2024-12-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105648
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105651.dly
#
# date created (size, mb): 2025-04-25 12:38:51.756388 (0.089)
#
# file min/max dates: 2000-12-01 / 2005-10-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105651
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105657.dly
#
# date created (size, mb): 2025-04-25 12:38:52.801497 (0.357)
#
# file min/max dates: 2000-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105657
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105660.dly
#
# date created (size, mb): 2025-04-25 12:38:55.7338 (1.743)
#
# file min/max dates: 1914-01-01 / 2011-03-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105660
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105669.dly
#
# date created (size, mb): 2025-04-25 12:38:57.445977 (0.252)
#
# file min/max dates: 2000-12-01 / 2011-06-30
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105669
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105672.dly
#
# date created (size, mb): 2025-04-25 12:38:58.446081 (0.307)
#
# file min/max dates: 2000-12-01 / 2024-09-30
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105672
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105675.dly
#
# date created (size, mb): 2025-04-25 12:38:59.118151 (0.029)
#
# file min/max dates: 2000-12-01 / 2002-06-30
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105675
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105681.dly
#
# date created (size, mb): 2025-04-25 12:39:00.794324 (0.549)
#
# file min/max dates: 2000-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105681
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105856.dly
#
# date created (size, mb): 2025-04-25 12:39:07.230991 (1.073)
#
# file min/max dates: 1959-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105856
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105857.dly
#
# date created (size, mb): 2025-04-25 12:39:10.462325 (0.955)
#
# file min/max dates: 1959-12-01 / 2013-10-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105857
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105858.dly
#
# date created (size, mb): 2025-04-25 12:39:13.881679 (1.127)
#
# file min/max dates: 1960-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105858
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105860.dly
#
# date created (size, mb): 2025-04-25 12:39:23.198644 (1.97)
#
# file min/max dates: 1906-01-01 / 2021-07-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105860
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105861.dly
#
# date created (size, mb): 2025-04-25 12:39:26.381974 (0.814)
#
# file min/max dates: 1960-01-01 / 2007-04-30
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105861
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105862.dly
#
# date created (size, mb): 2025-04-25 12:39:28.633207 (1.08)
#
# file min/max dates: 1959-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105862
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105863.dly
#
# date created (size, mb): 2025-04-25 12:39:31.107463 (1.053)
#
# file min/max dates: 1920-12-01 / 2004-12-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105863
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105864.dly
#
# date created (size, mb): 2025-04-25 12:39:33.128672 (0.784)
#
# file min/max dates: 1960-11-01 / 2004-06-30
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105864
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105865.dly
#
# date created (size, mb): 2025-04-25 12:39:35.284895 (0.93)
#
# file min/max dates: 1959-12-01 / 2013-01-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105865
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105866.dly
#
# date created (size, mb): 2025-04-25 12:39:39.310312 (1.486)
#
# file min/max dates: 1959-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105866
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105867.dly
#
# date created (size, mb): 2025-04-25 12:39:42.027594 (1.153)
#
# file min/max dates: 1959-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105867
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105869.dly
#
# date created (size, mb): 2025-04-25 12:39:44.951896 (1.149)
#
# file min/max dates: 1959-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105869
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105870.dly
#
# date created (size, mb): 2025-04-25 12:39:48.36325 (1.173)
#
# file min/max dates: 1959-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105870
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105871.dly
#
# date created (size, mb): 2025-04-25 12:39:51.535578 (1.164)
#
# file min/max dates: 1960-04-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105871
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105872.dly
#
# date created (size, mb): 2025-04-25 12:39:53.814814 (0.882)
#
# file min/max dates: 1959-12-01 / 2008-11-30
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105872
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105873.dly
#
# date created (size, mb): 2025-04-25 12:39:56.206062 (1.174)
#
# file min/max dates: 1959-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105873
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105874.dly
#
# date created (size, mb): 2025-04-25 12:39:58.418291 (0.796)
#
# file min/max dates: 1959-12-01 / 2005-04-30
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105874
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105875.dly
#
# date created (size, mb): 2025-04-25 12:40:00.843542 (1.151)
#
# file min/max dates: 1959-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105875
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105876.dly
#
# date created (size, mb): 2025-04-25 12:40:03.937862 (1.039)
#
# file min/max dates: 1959-12-01 / 2024-08-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105876
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105877.dly
#
# date created (size, mb): 2025-04-25 12:40:06.375115 (1.158)
#
# file min/max dates: 1959-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105877
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105878.dly
#
# date created (size, mb): 2025-04-25 12:40:08.970383 (1.134)
#
# file min/max dates: 1961-08-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105878
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105880.dly
#
# date created (size, mb): 2025-04-25 12:40:11.605656 (1.174)
#
# file min/max dates: 1959-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105880
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105881.dly
#
# date created (size, mb): 2025-04-25 12:40:15.607071 (1.519)
#
# file min/max dates: 1959-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105881
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105882.dly
#
# date created (size, mb): 2025-04-25 12:40:18.251344 (1.123)
#
# file min/max dates: 1959-12-01 / 2023-10-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105882
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105884.dly
#
# date created (size, mb): 2025-04-25 12:40:20.614589 (1.027)
#
# file min/max dates: 1959-12-01 / 2017-08-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105884
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105885.dly
#
# date created (size, mb): 2025-04-25 12:40:22.931829 (1.02)
#
# file min/max dates: 1959-12-01 / 2022-01-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105885
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105886.dly
#
# date created (size, mb): 2025-04-25 12:40:25.986145 (1.47)
#
# file min/max dates: 1959-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105886
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105887.dly
#
# date created (size, mb): 2025-04-25 12:40:29.182476 (1.067)
#
# file min/max dates: 1959-12-01 / 2022-12-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105887
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105888.dly
#
# date created (size, mb): 2025-04-25 12:40:31.695737 (1.162)
#
# file min/max dates: 1959-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105888
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105889.dly
#
# date created (size, mb): 2025-04-25 12:40:34.174993 (1.111)
#
# file min/max dates: 1959-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105889
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105890.dly
#
# date created (size, mb): 2025-04-25 12:40:36.282212 (0.823)
#
# file min/max dates: 1959-12-01 / 2006-04-30
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105890
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105891.dly
#
# date created (size, mb): 2025-04-25 12:40:39.088502 (1.14)
#
# file min/max dates: 1959-12-01 / 2023-06-30
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105891
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105892.dly
#
# date created (size, mb): 2025-04-25 12:40:41.942798 (1.107)
#
# file min/max dates: 1959-12-01 / 2023-03-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105892
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105893.dly
#
# date created (size, mb): 2025-04-25 12:40:44.426055 (1.149)
#
# file min/max dates: 1959-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105893
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105894.dly
#
# date created (size, mb): 2025-04-25 12:40:46.899311 (1.142)
#
# file min/max dates: 1959-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105894
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105895.dly
#
# date created (size, mb): 2025-04-25 12:40:50.437677 (1.962)
#
# file min/max dates: 1903-12-01 / 2017-12-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105895
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105897.dly
#
# date created (size, mb): 2025-04-25 12:40:54.017048 (1.068)
#
# file min/max dates: 1959-12-01 / 2024-11-30
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105897
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105898.dly
#
# date created (size, mb): 2025-04-25 12:40:56.951352 (1.507)
#
# file min/max dates: 1959-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105898
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105899.dly
#
# date created (size, mb): 2025-04-25 12:41:00.329701 (1.847)
#
# file min/max dates: 1889-01-01 / 2004-12-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105899
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105900.dly
#
# date created (size, mb): 2025-04-25 12:41:05.186204 (1.953)
#
# file min/max dates: 1916-01-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105900
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105901.dly
#
# date created (size, mb): 2025-04-25 12:41:08.013497 (1.145)
#
# file min/max dates: 1959-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105901
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105902.dly
#
# date created (size, mb): 2025-04-25 12:41:10.369741 (1.103)
#
# file min/max dates: 1959-12-01 / 2022-08-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105902
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105903.dly
#
# date created (size, mb): 2025-04-25 12:41:13.885105 (2.027)
#
# file min/max dates: 1910-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105903
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105904.dly
#
# date created (size, mb): 2025-04-25 12:41:19.035638 (2.51)
#
# file min/max dates: 1882-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105904
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105905.dly
#
# date created (size, mb): 2025-04-25 12:41:23.308081 (1.954)
#
# file min/max dates: 1874-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105905
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105906.dly
#
# date created (size, mb): 2025-04-25 12:41:26.080368 (1.166)
#
# file min/max dates: 1959-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105906
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105907.dly
#
# date created (size, mb): 2025-04-25 12:41:28.879658 (0.832)
#
# file min/max dates: 1959-12-01 / 2006-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105907
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105908.dly
#
# date created (size, mb): 2025-04-25 12:41:30.991876 (0.776)
#
# file min/max dates: 1959-12-01 / 2002-12-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105908
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105909.dly
#
# date created (size, mb): 2025-04-25 12:41:33.225108 (1.144)
#
# file min/max dates: 1959-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105909
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105910.dly
#
# date created (size, mb): 2025-04-25 12:41:36.33443 (1.156)
#
# file min/max dates: 1959-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105910
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105911.dly
#
# date created (size, mb): 2025-04-25 12:41:39.766785 (1.92)
#
# file min/max dates: 1899-12-01 / 2008-10-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105911
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105912.dly
#
# date created (size, mb): 2025-04-25 12:41:43.00012 (0.803)
#
# file min/max dates: 1959-12-01 / 2004-10-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105912
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105913.dly
#
# date created (size, mb): 2025-04-25 12:41:45.307359 (1.114)
#
# file min/max dates: 1959-12-01 / 2024-11-30
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105913
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105914.dly
#
# date created (size, mb): 2025-04-25 12:41:47.573593 (0.976)
#
# file min/max dates: 1959-12-01 / 2014-11-30
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105914
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105915.dly
#
# date created (size, mb): 2025-04-25 12:41:49.727816 (0.999)
#
# file min/max dates: 1959-12-01 / 2016-07-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105915
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105917.dly
#
# date created (size, mb): 2025-04-25 12:41:51.769028 (0.825)
#
# file min/max dates: 1959-12-01 / 2006-03-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105917
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105918.dly
#
# date created (size, mb): 2025-04-25 12:41:55.162379 (1.458)
#
# file min/max dates: 1960-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105918
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105919.dly
#
# date created (size, mb): 2025-04-25 12:41:57.844657 (1.166)
#
# file min/max dates: 1959-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105919
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105920.dly
#
# date created (size, mb): 2025-04-25 12:42:01.233008 (1.895)
#
# file min/max dates: 1910-12-01 / 2024-12-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105920
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105921.dly
#
# date created (size, mb): 2025-04-25 12:42:04.025297 (1.164)
#
# file min/max dates: 1959-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105921
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105922.dly
#
# date created (size, mb): 2025-04-25 12:42:07.065612 (0.917)
#
# file min/max dates: 1960-03-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105922
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105923.dly
#
# date created (size, mb): 2025-04-25 12:42:10.111927 (1.489)
#
# file min/max dates: 1959-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105923
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105924.dly
#
# date created (size, mb): 2025-04-25 12:42:12.45317 (0.781)
#
# file min/max dates: 1959-12-01 / 2003-09-30
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105924
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105925.dly
#
# date created (size, mb): 2025-04-25 12:42:14.563388 (0.944)
#
# file min/max dates: 1959-12-01 / 2012-12-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105925
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105926.dly
#
# date created (size, mb): 2025-04-25 12:42:17.586701 (1.143)
#
# file min/max dates: 1959-12-01 / 2024-10-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105926
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105927.dly
#
# date created (size, mb): 2025-04-25 12:42:20.318984 (0.797)
#
# file min/max dates: 1959-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105927
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105929.dly
#
# date created (size, mb): 2025-04-25 12:42:22.296189 (0.77)
#
# file min/max dates: 1959-12-01 / 2009-11-30
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105929
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105930.dly
#
# date created (size, mb): 2025-04-25 12:42:24.62343 (1.154)
#
# file min/max dates: 1959-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105930
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105931.dly
#
# date created (size, mb): 2025-04-25 12:42:27.081684 (0.943)
#
# file min/max dates: 1959-12-01 / 2012-12-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105931
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105932.dly
#
# date created (size, mb): 2025-04-25 12:42:30.208008 (1.029)
#
# file min/max dates: 1959-12-01 / 2017-09-30
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105932
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00105933.dly
#
# date created (size, mb): 2025-04-25 12:42:32.83428 (0.833)
#
# file min/max dates: 1959-12-01 / 2006-10-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00105933
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00107640.dly
#
# date created (size, mb): 2025-04-25 12:42:35.748582 (1.384)
#
# file min/max dates: 1959-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00107640
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00107650.dly
#
# date created (size, mb): 2025-04-25 12:42:39.186938 (1.52)
#
# file min/max dates: 1959-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00107650
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00107663.dly
#
# date created (size, mb): 2025-04-25 12:42:42.480279 (1.174)
#
# file min/max dates: 1959-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00107663
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00107962.dly
#
# date created (size, mb): 2025-04-25 12:42:45.466588 (1.071)
#
# file min/max dates: 1964-08-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00107962
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00108854.dly
#
# date created (size, mb): 2025-04-25 12:42:48.196871 (1.171)
#
# file min/max dates: 1959-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00108854
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00108855.dly
#
# date created (size, mb): 2025-04-25 12:42:50.60412 (0.846)
#
# file min/max dates: 1959-12-01 / 2007-07-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00108855
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00115807.dly
#
# date created (size, mb): 2025-04-25 12:42:51.940258 (0.351)
#
# file min/max dates: 2005-06-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00115807
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00115811.dly
#
# date created (size, mb): 2025-04-25 12:42:52.702337 (0.107)
#
# file min/max dates: 2004-12-01 / 2010-10-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00115811
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00156832.dly
#
# date created (size, mb): 2025-04-25 12:42:53.539424 (0.221)
#
# file min/max dates: 2012-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00156832
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00156836.dly
#
# date created (size, mb): 2025-04-25 12:42:54.785553 (0.221)
#
# file min/max dates: 2012-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00156836
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00156840.dly
#
# date created (size, mb): 2025-04-25 12:42:55.898668 (0.221)
#
# file min/max dates: 2012-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00156840
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00156844.dly
#
# date created (size, mb): 2025-04-25 12:42:56.792761 (0.219)
#
# file min/max dates: 2012-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00156844
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00156848.dly
#
# date created (size, mb): 2025-04-25 12:42:57.699855 (0.22)
#
# file min/max dates: 2012-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00156848
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00156852.dly
#
# date created (size, mb): 2025-04-25 12:43:01.550253 (2.577)
#
# file min/max dates: 1879-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00156852
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00156856.dly
#
# date created (size, mb): 2025-04-25 12:43:03.513457 (0.21)
#
# file min/max dates: 2012-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00156856
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00156860.dly
#
# date created (size, mb): 2025-04-25 12:43:04.375546 (0.22)
#
# file min/max dates: 2012-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00156860
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00156864.dly
#
# date created (size, mb): 2025-04-25 12:43:05.323644 (0.219)
#
# file min/max dates: 2012-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00156864
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00156868.dly
#
# date created (size, mb): 2025-04-25 12:43:06.44076 (0.221)
#
# file min/max dates: 2012-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00156868
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00156872.dly
#
# date created (size, mb): 2025-04-25 12:43:07.665887 (0.221)
#
# file min/max dates: 2012-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00156872
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00156876.dly
#
# date created (size, mb): 2025-04-25 12:43:08.649988 (0.22)
#
# file min/max dates: 2012-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00156876
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00156880.dly
#
# date created (size, mb): 2025-04-25 12:43:09.646092 (0.203)
#
# file min/max dates: 2013-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00156880
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00156884.dly
#
# date created (size, mb): 2025-04-25 12:43:14.321576 (2.116)
#
# file min/max dates: 1904-02-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00156884
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKE00156888.dly
#
# date created (size, mb): 2025-04-25 12:43:16.064756 (0.202)
#
# file min/max dates: 2013-12-01 / 2025-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKE00156888
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKM00003014.dly
#
# date created (size, mb): 2025-04-25 12:43:16.828835 (0.181)
#
# file min/max dates: 1984-08-01 / 2016-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKM00003017.dly
#
# date created (size, mb): 2025-04-25 12:43:19.86815 (1.3)
#
# file min/max dates: 1973-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKM00003066.dly
#
# date created (size, mb): 2025-04-25 12:43:22.796453 (1.304)
#
# file min/max dates: 1973-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKM00003091.dly
#
# date created (size, mb): 2025-04-25 12:43:25.646748 (1.484)
#
# file min/max dates: 1929-10-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKM00003100.dly
#
# date created (size, mb): 2025-04-25 12:43:28.638058 (1.307)
#
# file min/max dates: 1937-03-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKM00003171.dly
#
# date created (size, mb): 2025-04-25 12:43:32.960506 (1.294)
#
# file min/max dates: 1973-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKM00003257.dly
#
# date created (size, mb): 2025-04-25 12:43:35.767796 (1.423)
#
# file min/max dates: 1973-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKM00003334.dly
#
# date created (size, mb): 2025-04-25 12:43:38.221051 (0.924)
#
# file min/max dates: 1973-01-01 / 2008-01-31
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKM00003414.dly
#
# date created (size, mb): 2025-04-25 12:43:40.802318 (1.423)
#
# file min/max dates: 1973-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKM00003502.dly
#
# date created (size, mb): 2025-04-25 12:43:44.282678 (1.257)
#
# file min/max dates: 1973-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKM00003590.dly
#
# date created (size, mb): 2025-04-25 12:43:47.526014 (1.278)
#
# file min/max dates: 1973-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKM00003740.dly
#
# date created (size, mb): 2025-04-25 12:43:50.464318 (1.264)
#
# file min/max dates: 1973-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKM00003772.dly
#
# date created (size, mb): 2025-04-25 12:43:53.267608 (1.397)
#
# file min/max dates: 1948-12-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKM00003862.dly
#
# date created (size, mb): 2025-04-25 12:43:56.545948 (1.28)
#
# file min/max dates: 1973-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKM00003917.dly
#
# date created (size, mb): 2025-04-25 12:43:59.736278 (1.278)
#
# file min/max dates: 1939-08-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKW00015014.dly
#
# date created (size, mb): 2025-04-25 12:44:00.953404 (0.17)
#
# file min/max dates: 1954-03-01 / 1957-04-30
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKW00015014
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKW00015015.dly
#
# date created (size, mb): 2025-04-25 12:44:01.840496 (0.292)
#
# file min/max dates: 1956-06-01 / 1962-08-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKW00015015
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKW00015018.dly
#
# date created (size, mb): 2025-04-25 12:44:02.627578 (0.054)
#
# file min/max dates: 1950-11-01 / 1951-10-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKW00015018
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKW00015027.dly
#
# date created (size, mb): 2025-04-25 12:44:03.793698 (0.555)
#
# file min/max dates: 1946-01-01 / 1959-04-30
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKW00015027
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKW00015033.dly
#
# date created (size, mb): 2025-04-25 12:44:05.464871 (0.765)
#
# file min/max dates: 1955-09-01 / 1967-12-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKW00015033
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKW00015034.dly
#
# date created (size, mb): 2025-04-25 12:44:06.572986 (0.066)
#
# file min/max dates: 1950-10-01 / 1951-12-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKW00015034
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKW00015035.dly
#
# date created (size, mb): 2025-04-25 12:44:07.054036 (0.032)
#
# file min/max dates: 1950-09-01 / 1951-03-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKW00015035
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKW00015036.dly
#
# date created (size, mb): 2025-04-25 12:44:09.295268 (0.816)
#
# file min/max dates: 1951-08-01 / 1965-04-30
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKW00015036
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKW00015037.dly
#
# date created (size, mb): 2025-04-25 12:44:11.749522 (0.914)
#
# file min/max dates: 1951-11-01 / 1967-12-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKW00015037
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKW00015038.dly
#
# date created (size, mb): 2025-04-25 12:44:13.422695 (0.664)
#
# file min/max dates: 1952-06-01 / 1964-06-30
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKW00015038
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKW00015040.dly
#
# date created (size, mb): 2025-04-25 12:44:14.879846 (0.562)
#
# file min/max dates: 1954-01-01 / 1967-04-30
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKW00015040
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKW00015041.dly
#
# date created (size, mb): 2025-04-25 12:44:15.801942 (0.07)
#
# file min/max dates: 1954-10-01 / 1957-03-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKW00015041
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKW00015042.dly
#
# date created (size, mb): 2025-04-25 12:44:16.595024 (0.28)
#
# file min/max dates: 1957-07-01 / 1962-08-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKW00015042
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKW00035034.dly
#
# date created (size, mb): 2025-04-25 12:44:18.496221 (1.084)
#
# file min/max dates: 1949-05-01 / 1967-12-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKW00035034
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKW00035035.dly
#
# date created (size, mb): 2025-04-25 12:44:19.600335 (0.083)
#
# file min/max dates: 1949-04-01 / 1951-01-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKW00035035
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKW00035036.dly
#
# date created (size, mb): 2025-04-25 12:44:21.690552 (0.785)
#
# file min/max dates: 1949-06-01 / 1964-03-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKW00035036
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKW00035046.dly
#
# date created (size, mb): 2025-04-25 12:44:24.023793 (0.929)
#
# file min/max dates: 1950-07-01 / 1967-12-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKW00035046
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKW00035047.dly
#
# date created (size, mb): 2025-04-25 12:44:27.08511 (1.721)
#
# file min/max dates: 1935-10-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKW00035048.dly
#
# date created (size, mb): 2025-04-25 12:44:29.610372 (1.008)
#
# file min/max dates: 1951-06-01 / 1967-12-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKW00035048
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKW00035049.dly
#
# date created (size, mb): 2025-04-25 12:44:31.107527 (0.35)
#
# file min/max dates: 1951-07-01 / 1958-12-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKW00035049
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKW00035050.dly
#
# date created (size, mb): 2025-04-25 12:44:33.284752 (1.002)
#
# file min/max dates: 1952-05-01 / 1967-12-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKW00035050
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKW00035051.dly
#
# date created (size, mb): 2025-04-25 12:44:35.842017 (0.843)
#
# file min/max dates: 1952-11-01 / 1967-12-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKW00035051
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKW00035052.dly
#
# date created (size, mb): 2025-04-25 12:44:37.185156 (0.063)
#
# file min/max dates: 1954-12-01 / 1958-08-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKW00035052
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UKW00035054.dly
#
# date created (size, mb): 2025-04-25 12:44:37.966237 (0.2)
#
# file min/max dates: 1960-12-01 / 1964-06-30
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  UKW00035054
# Any other monitors were successfully pulled from GHCN.”
# plot without title

# %% [markdown]
# # 5.European GSN station daily mean temperature download 2023

# %%
# ==== Filter European GSN stations ====
europe_gsn_ids <- stations %>%
  filter(latitude > 35, latitude < 72,
         longitude > -10, longitude < 40,
         gsn_flag == "GSN") %>%
  pull(id)

length(europe_gsn_ids)
get_multi_station_data <- function(id_list, region_label,
                                   var = "TAVG",
                                   date_min = "2023-06-01",
                                   date_max = "2023-09-30") {
  message(paste("Fetching", region_label, "station data. Total:", length(id_list)))

  pb <- progress_bar$new(
    format = paste0(region_label, " Progress [:bar] :percent | Completed: :current/:total"),
    total = length(id_list),
    clear = FALSE,
    width = 60
  )

  all_data <- purrr::map_dfr(id_list, function(station_id) {
    pb$tick()
    tryCatch({
      df <- meteo_pull_monitors(monitors = station_id,
                                var = var,
                                date_min = date_min,
                                date_max = date_max)
      df[[tolower(var)]] <- df[[tolower(var)]] / 10  # Convert from tenths °C to °C
      df$region <- region_label
      return(df)
    }, error = function(e) {
      return(NULL)
    })
  })

  return(all_data)
}

europe_data <- get_multi_station_data(europe_gsn_ids, "Europe",
                                      var = "TAVG",
                                      date_min = "2023-06-01",
                                      date_max = "2023-09-30")

write.csv(europe_data, "europe_temperature_gsn_2023.csv", row.names = FALSE)
europe_clean <- europe_data %>%
  filter(!is.na(tavg))

europe_avg_daily <- europe_clean %>%
  group_by(date) %>%
  summarise(avg_temp = mean(tavg)) %>%
  ungroup()

write.csv(europe_avg_daily, "europe_avg_temperature_2023_Jun-Sep.csv", row.names = FALSE)

library(ggplot2)

ggplot(europe_avg_daily, aes(x = as.Date(date), y = avg_temp)) +
  geom_line(color = "royalblue", linewidth = 1) +
  labs(
    title = "Daily Average Temperature at European GSN Stations (Jun 1 – Sep 30, 2023)",
    x = "Date", y = "Average Temperature (°C)"
  ) +
  theme_minimal()
# Out:
# [1] 102
# Fetching Europe station data. Total: 102
#
# file min/max dates: 1940-01-01 / 2025-04-30
#
# file min/max dates: 1973-02-01 / 2025-04-30
#
# file min/max dates: 1876-01-01 / 2025-04-30
#
# file min/max dates: 1855-02-01 / 2025-04-30
#
# file min/max dates: 1886-11-01 / 2024-04-30
#
# file min/max dates: 1833-01-01 / 2025-04-30
#
# file min/max dates: 1897-10-01 / 2025-03-31
#
# file min/max dates: 1881-01-01 / 2025-04-30
#
# file min/max dates: 1873-12-01 / 2000-12-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  DA000030380
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1973-01-01 / 2021-05-31
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/EI000003980.dly
#
# date created (size, mb): 2025-04-25 12:34:49.970352 (2.179)
#
# file min/max dates: 1885-01-01 / 2025-02-28
#
# file min/max dates: 1901-01-01 / 2025-04-30
#
# file min/max dates: 1906-05-01 / 2025-04-30
#
# file min/max dates: 1951-01-01 / 2025-04-30
#
# file min/max dates: 1957-04-01 / 2025-04-30
#
# file min/max dates: 1908-01-01 / 2025-04-30
#
# file min/max dates: 1944-11-01 / 2025-02-28
#
# file min/max dates: 1923-05-01 / 2025-02-28
#
# file min/max dates: 1945-03-01 / 2025-02-28
#
# file min/max dates: 1896-01-01 / 2025-01-31
#
# file min/max dates: 1947-01-01 / 2025-02-28
#
# file min/max dates: 1921-01-01 / 2025-02-28
#
# file min/max dates: 1891-01-01 / 2025-02-28
#
# file min/max dates: 1906-04-01 / 2025-02-28
#
# file min/max dates: 1781-01-01 / 2025-02-28
#
# file min/max dates: 1934-05-01 / 2025-02-28
#
# file min/max dates: 1955-01-01 / 2025-04-30
#
# file min/max dates: 1956-01-01 / 2023-07-31
#
# file min/max dates: 1978-04-01 / 2025-04-30
#
# file min/max dates: 1958-07-01 / 2025-04-30
#
# file min/max dates: 1860-12-01 / 2025-04-30
#
# file min/max dates: 1901-01-01 / 2024-04-30
#
# file min/max dates: 1951-01-01 / 2025-04-30
#
# file min/max dates: 1951-01-01 / 2024-12-31
#
# file min/max dates: 1951-01-01 / 2025-01-31
#
# file min/max dates: 1954-10-01 / 2025-04-30
#
# file min/max dates: 1951-11-01 / 2025-04-30
#
# file min/max dates: 1921-12-01 / 2025-04-30
#
# file min/max dates: 1881-01-01 / 2025-03-31
#
# file min/max dates: 1881-01-01 / 2025-04-30
#
# file min/max dates: 1951-01-01 / 2024-12-31
#
# file min/max dates: 1947-01-01 / 2025-04-30
#
# file min/max dates: 1886-11-01 / 2025-04-30
#
# file min/max dates: 1973-06-01 / 2025-04-30
#
# file min/max dates: 1956-01-01 / 2025-04-30
#
# file min/max dates: 1901-01-01 / 2025-04-30
#
# file min/max dates: 1920-07-01 / 2025-04-30
#
# file min/max dates: 1963-04-01 / 2004-02-29
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  NO000001212
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1911-01-01 / 2025-04-30
#
# file min/max dates: 2004-05-01 / 2009-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  NO000011520
# Any other monitors were successfully pulled from GHCN.”
# file min/max dates: 1943-01-01 / 2025-04-30
#
# file min/max dates: 1951-01-01 / 2025-04-30
#
# file min/max dates: 1923-01-01 / 2025-04-30
#
# file min/max dates: 1966-01-01 / 2025-04-30
#
# file min/max dates: 1966-01-01 / 2025-04-30
#
# file min/max dates: 1900-12-01 / 2025-01-31
#
# file min/max dates: 1961-01-01 / 2025-04-30
#
# file min/max dates: 1928-01-01 / 2025-04-30
#
# file min/max dates: 1952-03-01 / 2025-04-30
#
# file min/max dates: 1936-01-01 / 2025-04-30
#
# file min/max dates: 1912-09-01 / 2025-04-30
#
# file min/max dates: 1916-12-01 / 2025-04-30
#
# file min/max dates: 1945-01-01 / 2025-04-30
#
# file min/max dates: 1881-01-01 / 2025-04-30
#
# file min/max dates: 1881-01-01 / 2025-04-30
#
# file min/max dates: 1959-01-01 / 2025-04-30
#
# file min/max dates: 1944-01-01 / 2025-03-31
#
# file min/max dates: 1955-01-01 / 2025-04-30
#
# file min/max dates: 1936-12-01 / 2025-04-30
#
# file min/max dates: 1936-12-01 / 2022-01-31
#
# file min/max dates: 1918-06-01 / 2025-04-30
#
# file min/max dates: 1938-01-01 / 2019-06-30
#
# file min/max dates: 1916-04-01 / 2025-04-30
#
# file min/max dates: 1924-03-01 / 2025-02-28
#
# file min/max dates: 1945-01-01 / 2025-04-30
#
# file min/max dates: 1946-01-01 / 2025-04-30
#
# file min/max dates: 1901-01-01 / 2025-04-30
#
# file min/max dates: 1955-12-01 / 2025-04-30
#
# file min/max dates: 1961-05-01 / 2025-02-28
#
# file min/max dates: 1862-04-01 / 2005-06-30
#
# file min/max dates: 2005-05-01 / 2025-02-28
#
# file min/max dates: 2008-10-01 / 2025-02-28
#
# file min/max dates: 1995-12-01 / 2025-02-28
#
# file min/max dates: 1928-09-01 / 2024-04-30
#
# file min/max dates: 1882-09-01 / 2025-04-30
#
# file min/max dates: 1864-01-01 / 2025-04-30
#
# file min/max dates: 1943-07-01 / 2025-04-30
#
# file min/max dates: 1929-01-01 / 2007-05-31
#
# file min/max dates: 1930-01-01 / 2025-04-30
#
# file min/max dates: 1929-02-01 / 2025-04-30
#
# file min/max dates: 1929-01-01 / 2025-04-30
#
# file min/max dates: 1953-09-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UK000003005.dly
#
# date created (size, mb): 2025-04-25 12:34:54.591831 (2.247)
#
# file min/max dates: 1929-10-01 / 2025-03-31
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UK000003026.dly
#
# date created (size, mb): 2025-04-25 12:34:59.494339 (2.908)
#
# file min/max dates: 1873-07-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UK000003162.dly
#
# date created (size, mb): 2025-04-25 12:35:04.234829 (1.854)
#
# file min/max dates: 1931-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UK000003302.dly
#
# date created (size, mb): 2025-04-25 12:35:08.017221 (1.916)
#
# file min/max dates: 1930-12-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UK000003377.dly
#
# date created (size, mb): 2025-04-25 12:35:11.666599 (1.843)
#
# file min/max dates: 1949-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UK000003808.dly
#
# date created (size, mb): 2025-04-25 12:35:15.189964 (1.275)
#
# file min/max dates: 1973-01-01 / 2025-04-30
#
# file min/max dates: 1924-04-01 / 2025-04-30
#
# file min/max dates: 1936-01-01 / 2025-04-30
#
# file min/max dates: 1885-09-01 / 2025-04-30
#
# file min/max dates: 1910-01-01 / 2019-12-31
# plot without title

# %% [markdown]
# # 6.European GSN station daily mean temperature download 2024

# %%
europe_data_2024 <- get_multi_station_data(europe_gsn_ids, "Europe",
                                           var = "TAVG",
                                           date_min = "2024-06-01",
                                           date_max = "2024-09-30")

write.csv(europe_data_2024, "europe_temperature_gsn_2024.csv", row.names = FALSE)

europe_clean_2024 <- europe_data_2024 %>%
  filter(!is.na(tavg))

europe_avg_daily_2024 <- europe_clean_2024 %>%
  group_by(date) %>%
  summarise(avg_temp = mean(tavg)) %>%
  ungroup()

write.csv(europe_avg_daily_2024, "europe_avg_temperature_2024_Jun-Sep.csv", row.names = FALSE)

ggplot(europe_avg_daily_2024, aes(x = as.Date(date), y = avg_temp)) +
  geom_line(color = "darkorange", linewidth = 1) +
  labs(
    title = "Daily Average Temperature at European GSN Stations (Jun 1 – Sep 30, 2024)",
    x = "Date", y = "Average Temperature (°C)"
  ) +
  theme_minimal()
# Out:
# Fetching Europe station data. Total: 102
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/AG000060390.dly
#
# date created (size, mb): 2025-04-25 12:48:52.242566 (1.911)
#
# file min/max dates: 1940-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/ALM00013615.dly
#
# date created (size, mb): 2025-04-25 12:48:54.441793 (0.628)
#
# file min/max dates: 1973-02-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/AU000005010.dly
#
# date created (size, mb): 2025-04-25 12:49:00.023371 (3.076)
#
# file min/max dates: 1876-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/AU000005901.dly
#
# date created (size, mb): 2025-04-25 12:49:07.547151 (3.703)
#
# file min/max dates: 1855-02-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/AU000015410.dly
#
# date created (size, mb): 2025-04-25 12:49:15.410965 (3.308)
#
# file min/max dates: 1886-11-01 / 2024-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/BE000006447.dly
#
# date created (size, mb): 2025-04-25 12:49:22.663716 (3.538)
#
# file min/max dates: 1833-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/BKM00014652.dly
#
# date created (size, mb): 2025-04-25 12:49:27.076173 (1.526)
#
# file min/max dates: 1897-10-01 / 2025-03-31
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/BOM00033038.dly
#
# date created (size, mb): 2025-04-25 12:49:31.776659 (2.886)
#
# file min/max dates: 1881-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/DA000030380.dly
#
# date created (size, mb): 2025-04-25 12:49:37.320233 (2.369)
#
# file min/max dates: 1873-12-01 / 2000-12-31
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  DA000030380
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/DAM00006011.dly
#
# date created (size, mb): 2025-04-25 12:49:40.47656 (1.235)
#
# file min/max dates: 1973-01-01 / 2021-05-31
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/EI000003980.dly
#
# date created (size, mb): 2025-04-25 12:34:49.970352 (2.179)
#
# file min/max dates: 1885-01-01 / 2025-02-28
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/EN000026242.dly
#
# date created (size, mb): 2025-04-25 12:49:46.772212 (2.639)
#
# file min/max dates: 1901-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/EZ000011464.dly
#
# date created (size, mb): 2025-04-25 12:49:51.547707 (2.135)
#
# file min/max dates: 1906-05-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/FI000002401.dly
#
# date created (size, mb): 2025-04-25 12:49:55.3461 (1.889)
#
# file min/max dates: 1951-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/FI000002963.dly
#
# date created (size, mb): 2025-04-25 12:50:00.07559 (1.685)
#
# file min/max dates: 1957-04-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/FI000007501.dly
#
# date created (size, mb): 2025-04-25 12:50:04.743073 (2.706)
#
# file min/max dates: 1908-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/FR000007130.dly
#
# date created (size, mb): 2025-04-25 12:50:08.878501 (1.783)
#
# file min/max dates: 1944-11-01 / 2025-02-28
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/FR000007190.dly
#
# date created (size, mb): 2025-04-25 12:50:13.836015 (2.165)
#
# file min/max dates: 1923-05-01 / 2025-02-28
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/FR000007255.dly
#
# date created (size, mb): 2025-04-25 12:50:17.486392 (1.796)
#
# file min/max dates: 1945-03-01 / 2025-02-28
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/FR000007560.dly
#
# date created (size, mb): 2025-04-25 12:50:21.303788 (2.033)
#
# file min/max dates: 1896-01-01 / 2025-01-31
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/FR000007630.dly
#
# date created (size, mb): 2025-04-25 12:50:25.628236 (1.749)
#
# file min/max dates: 1947-01-01 / 2025-02-28
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/FR000007650.dly
#
# date created (size, mb): 2025-04-25 12:50:29.943682 (2.235)
#
# file min/max dates: 1921-01-01 / 2025-02-28
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/GM000010147.dly
#
# date created (size, mb): 2025-04-25 12:50:36.471358 (3.338)
#
# file min/max dates: 1891-01-01 / 2025-02-28
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/GM000010393.dly
#
# date created (size, mb): 2025-04-25 12:50:42.145946 (2.657)
#
# file min/max dates: 1906-04-01 / 2025-02-28
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/GM000010962.dly
#
# date created (size, mb): 2025-04-25 12:50:49.363693 (3.963)
#
# file min/max dates: 1781-01-01 / 2025-02-28
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/GMW00035032.dly
#
# date created (size, mb): 2025-04-25 12:50:55.275305 (2.501)
#
# file min/max dates: 1934-05-01 / 2025-02-28
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/GR000016641.dly
#
# date created (size, mb): 2025-04-25 12:50:58.907681 (1.653)
#
# file min/max dates: 1955-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/GR000016734.dly
#
# date created (size, mb): 2025-04-25 12:51:02.745079 (1.563)
#
# file min/max dates: 1956-01-01 / 2023-07-31
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/GR000167230.dly
#
# date created (size, mb): 2025-04-25 12:51:05.289342 (1.141)
#
# file min/max dates: 1978-04-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/GR000167460.dly
#
# date created (size, mb): 2025-04-25 12:51:08.084632 (1.482)
#
# file min/max dates: 1958-07-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/HR000142360.dly
#
# date created (size, mb): 2025-04-25 12:51:13.649208 (2.939)
#
# file min/max dates: 1860-12-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/HU000012942.dly
#
# date created (size, mb): 2025-04-25 12:51:19.65783 (2.597)
#
# file min/max dates: 1901-01-01 / 2024-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/IT000016134.dly
#
# date created (size, mb): 2025-04-25 12:51:23.478225 (1.586)
#
# file min/max dates: 1951-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/IT000016550.dly
#
# date created (size, mb): 2025-04-25 12:51:27.307622 (1.58)
#
# file min/max dates: 1951-01-01 / 2024-12-31
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/IT000160220.dly
#
# date created (size, mb): 2025-04-25 12:51:30.525955 (1.663)
#
# file min/max dates: 1951-01-01 / 2025-01-31
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/IT000162240.dly
#
# date created (size, mb): 2025-04-25 12:51:33.254238 (1.18)
#
# file min/max dates: 1954-10-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/IT000162580.dly
#
# date created (size, mb): 2025-04-25 12:51:35.749496 (1.253)
#
# file min/max dates: 1951-11-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/JNM00001001.dly
#
# date created (size, mb): 2025-04-25 12:51:40.110948 (2.129)
#
# file min/max dates: 1921-12-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/LG000026406.dly
#
# date created (size, mb): 2025-04-25 12:51:44.989453 (2.938)
#
# file min/max dates: 1881-01-01 / 2025-03-31
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/LH000026730.dly
#
# date created (size, mb): 2025-04-25 12:51:51.748153 (3.324)
#
# file min/max dates: 1881-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/LO000011934.dly
#
# date created (size, mb): 2025-04-25 12:51:56.043597 (1.781)
#
# file min/max dates: 1951-01-01 / 2024-12-31
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/LU000006590.dly
#
# date created (size, mb): 2025-04-25 12:51:59.598966 (1.852)
#
# file min/max dates: 1947-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/MD000033815.dly
#
# date created (size, mb): 2025-04-25 12:52:04.946519 (2.647)
#
# file min/max dates: 1886-11-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/MK000013577.dly
#
# date created (size, mb): 2025-04-25 12:52:08.094845 (1.114)
#
# file min/max dates: 1973-06-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/MT000016597.dly
#
# date created (size, mb): 2025-04-25 12:52:11.04015 (1.633)
#
# file min/max dates: 1956-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/NLM00006260.dly
#
# date created (size, mb): 2025-04-25 12:52:16.950762 (2.973)
#
# file min/max dates: 1901-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/NO000001026.dly
#
# date created (size, mb): 2025-04-25 12:52:21.997285 (2.616)
#
# file min/max dates: 1920-07-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/NO000001212.dly
#
# date created (size, mb): 2025-04-25 12:52:24.913587 (0.779)
#
# file min/max dates: 1963-04-01 / 2004-02-29
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  NO000001212
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/NO000001465.dly
#
# date created (size, mb): 2025-04-25 12:52:29.049015 (1.925)
#
# file min/max dates: 1911-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/NO000011520.dly
#
# date created (size, mb): 2025-04-25 12:52:30.417157 (0.06)
#
# file min/max dates: 2004-05-01 / 2009-02-28
#
# Warning message in meteo_pull_monitors(monitors = station_id, var = var, date_min = date_min, :
# “The following stations could not be pulled from the GHCN ftp:
#  NO000011520
# Any other monitors were successfully pulled from GHCN.”
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/NO000014030.dly
#
# date created (size, mb): 2025-04-25 12:52:33.135438 (1.679)
#
# file min/max dates: 1943-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/NO000098550.dly
#
# date created (size, mb): 2025-04-25 12:52:36.381774 (1.668)
#
# file min/max dates: 1951-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/NOM00001238.dly
#
# date created (size, mb): 2025-04-25 12:52:41.675323 (2.341)
#
# file min/max dates: 1923-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/PL000012120.dly
#
# date created (size, mb): 2025-04-25 12:52:45.049672 (1.476)
#
# file min/max dates: 1966-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/PL000012385.dly
#
# date created (size, mb): 2025-04-25 12:52:48.345013 (1.498)
#
# file min/max dates: 1966-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/PO000008535.dly
#
# date created (size, mb): 2025-04-25 12:52:52.961491 (2.122)
#
# file min/max dates: 1900-12-01 / 2025-01-31
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/ROM00015085.dly
#
# date created (size, mb): 2025-04-25 12:52:56.22983 (1.244)
#
# file min/max dates: 1961-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/ROM00015280.dly
#
# date created (size, mb): 2025-04-25 12:52:59.961216 (2.08)
#
# file min/max dates: 1928-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/ROM00015360.dly
#
# date created (size, mb): 2025-04-25 12:53:03.891623 (1.713)
#
# file min/max dates: 1952-03-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/RSM00022113.dly
#
# date created (size, mb): 2025-04-25 12:53:09.169169 (2.425)
#
# file min/max dates: 1936-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/RSM00022217.dly
#
# date created (size, mb): 2025-04-25 12:53:14.318702 (2.914)
#
# file min/max dates: 1912-09-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/RSM00022520.dly
#
# date created (size, mb): 2025-04-25 12:53:20.031294 (2.66)
#
# file min/max dates: 1916-12-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/RSM00022802.dly
#
# date created (size, mb): 2025-04-25 12:53:24.33574 (2.114)
#
# file min/max dates: 1945-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/RSM00022837.dly
#
# date created (size, mb): 2025-04-25 12:53:30.591388 (3.153)
#
# file min/max dates: 1881-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/RSM00026063.dly
#
# date created (size, mb): 2025-04-25 12:53:36.930044 (3.629)
#
# file min/max dates: 1881-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/RSM00026359.dly
#
# date created (size, mb): 2025-04-25 12:53:41.868555 (1.589)
#
# file min/max dates: 1959-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/RSM00026781.dly
#
# date created (size, mb): 2025-04-25 12:53:46.06799 (2.025)
#
# file min/max dates: 1944-01-01 / 2025-03-31
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/RSM00026997.dly
#
# date created (size, mb): 2025-04-25 12:53:49.766373 (1.821)
#
# file min/max dates: 1955-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/RSM00027037.dly
#
# date created (size, mb): 2025-04-25 12:53:54.789893 (2.269)
#
# file min/max dates: 1936-12-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/RSM00027612.dly
#
# date created (size, mb): 2025-04-25 12:53:58.825311 (1.908)
#
# file min/max dates: 1936-12-01 / 2022-01-31
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/RSM00034123.dly
#
# date created (size, mb): 2025-04-25 12:54:03.385783 (2.619)
#
# file min/max dates: 1918-06-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/RSM00034927.dly
#
# date created (size, mb): 2025-04-25 12:54:08.18128 (1.883)
#
# file min/max dates: 1938-01-01 / 2019-06-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/SP000008027.dly
#
# date created (size, mb): 2025-04-25 12:54:12.14069 (2.155)
#
# file min/max dates: 1916-04-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/SP000008181.dly
#
# date created (size, mb): 2025-04-25 12:54:15.928082 (1.918)
#
# file min/max dates: 1924-03-01 / 2025-02-28
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/SP000008202.dly
#
# date created (size, mb): 2025-04-25 12:54:20.521557 (1.77)
#
# file min/max dates: 1945-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/SP000008215.dly
#
# date created (size, mb): 2025-04-25 12:54:24.098928 (1.875)
#
# file min/max dates: 1946-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/SP000008280.dly
#
# date created (size, mb): 2025-04-25 12:54:28.298363 (2.239)
#
# file min/max dates: 1901-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/SP000008410.dly
#
# date created (size, mb): 2025-04-25 12:54:32.672816 (1.513)
#
# file min/max dates: 1955-12-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/SP000060338.dly
#
# date created (size, mb): 2025-04-25 12:54:35.865146 (1.503)
#
# file min/max dates: 1961-05-01 / 2025-02-28
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/SWE00100026.dly
#
# date created (size, mb): 2025-04-25 12:54:41.034681 (3.224)
#
# file min/max dates: 1862-04-01 / 2005-06-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/SWE00140178.dly
#
# date created (size, mb): 2025-04-25 12:54:44.524043 (0.471)
#
# file min/max dates: 2005-05-01 / 2025-02-28
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/SWE00140622.dly
#
# date created (size, mb): 2025-04-25 12:54:45.75217 (0.393)
#
# file min/max dates: 2008-10-01 / 2025-02-28
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/SWM00002589.dly
#
# date created (size, mb): 2025-04-25 12:54:47.318332 (0.661)
#
# file min/max dates: 1995-12-01 / 2025-02-28
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/SY000040022.dly
#
# date created (size, mb): 2025-04-25 12:54:49.991609 (1.498)
#
# file min/max dates: 1928-09-01 / 2024-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/SZ000002220.dly
#
# date created (size, mb): 2025-04-25 12:54:55.722202 (3.357)
#
# file min/max dates: 1882-09-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/SZ000006717.dly
#
# date created (size, mb): 2025-04-25 12:55:00.797728 (2.064)
#
# file min/max dates: 1864-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/TS000060725.dly
#
# date created (size, mb): 2025-04-25 12:55:04.097069 (1.466)
#
# file min/max dates: 1943-07-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/TU000017062.dly
#
# date created (size, mb): 2025-04-25 12:55:07.67844 (1.371)
#
# file min/max dates: 1929-01-01 / 2007-05-31
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/TU000017074.dly
#
# date created (size, mb): 2025-04-25 12:55:11.691856 (1.952)
#
# file min/max dates: 1930-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/TU000017090.dly
#
# date created (size, mb): 2025-04-25 12:55:15.825284 (2.127)
#
# file min/max dates: 1929-02-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/TU000017240.dly
#
# date created (size, mb): 2025-04-25 12:55:20.556774 (2.119)
#
# file min/max dates: 1929-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/TU000017375.dly
#
# date created (size, mb): 2025-04-25 12:55:24.102141 (1.43)
#
# file min/max dates: 1953-09-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UK000003005.dly
#
# date created (size, mb): 2025-04-25 12:34:54.591831 (2.247)
#
# file min/max dates: 1929-10-01 / 2025-03-31
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UK000003026.dly
#
# date created (size, mb): 2025-04-25 12:34:59.494339 (2.908)
#
# file min/max dates: 1873-07-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UK000003162.dly
#
# date created (size, mb): 2025-04-25 12:35:04.234829 (1.854)
#
# file min/max dates: 1931-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UK000003302.dly
#
# date created (size, mb): 2025-04-25 12:35:08.017221 (1.916)
#
# file min/max dates: 1930-12-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UK000003377.dly
#
# date created (size, mb): 2025-04-25 12:35:11.666599 (1.843)
#
# file min/max dates: 1949-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UK000003808.dly
#
# date created (size, mb): 2025-04-25 12:35:15.189964 (1.275)
#
# file min/max dates: 1973-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UPM00033317.dly
#
# date created (size, mb): 2025-04-25 12:55:35.365307 (2.128)
#
# file min/max dates: 1924-04-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UPM00033377.dly
#
# date created (size, mb): 2025-04-25 12:55:39.469732 (2.271)
#
# file min/max dates: 1936-01-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UPM00033587.dly
#
# date created (size, mb): 2025-04-25 12:55:45.495356 (2.866)
#
# file min/max dates: 1885-09-01 / 2025-04-30
#
# using cached file: /root/.cache/R/rnoaa/noaa_ghcnd/UPM00033915.dly
#
# date created (size, mb): 2025-04-25 12:55:50.446869 (2.245)
#
# file min/max dates: 1910-01-01 / 2019-12-31
# plot without title
